# %% [markdown]
# <a href="https://colab.research.google.com/github/brunobro/dataset-cowpea-cultivars-with-residual-organomineral-fertilizers-from-crop-corn-cultivation/blob/main/DatasetCowpeaCultivarsWithResidualOrganomineralFertilizersFromCropCornCultivation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dataset: Cowpea Cultivars with Residual Organomineral Fertilizers from Crop Corn Cultivation**
#
# **Authors:**
# Carlos Henrique Conceição Sousa, Alan Mario Zuffo, Bruno Rodrigues de Oliveira, Francisco Charles dos Santos Silva,  Ricardo Mezzomo, Leandra Matos Barrozo, Tatiane Scilewski da Costa Zanatta, Joel Cabral dos Santos, Yago Pinto Coelho, Aurilucia do Nascimento Silva Caldas,

# %%
import pandas as pd

df = pd.read_excel('data.xlsx')
df
# Out:
#       System   Cultivar Fertilizing  Repetition  ND        GL   LP        TG  \
# 0    Without  Tucumaque        Org1           1  20  5.100000  2.2  623.4990
# 1    Without  Tucumaque        Org1           2  31  3.612903  6.2  618.7640
# 2    Without  Tucumaque        Org1           3  18  1.388889  4.4  482.3230
# 3    Without   Nova Era        Org1           1  32  5.000000  3.6  508.8730
# 4    Without   Nova Era        Org1           2  30  6.400000  4.4  498.5750
# 5    Without   Nova Era        Org1           3  38  4.473684  4.2  487.0690
# 6    Without  Tucumaque        Org2           1  25  5.000000  3.4  583.1780
# 7    Without  Tucumaque        Org2           2  29  4.448276  3.8  574.1250
# 8    Without  Tucumaque        Org2           3  19  2.473684  4.4  467.5640
# 9    Without   Nova Era        Org2           1  41  4.414634  4.2  498.9250
# 10   Without   Nova Era        Org2           2  52  4.500000  4.0  505.0620
# ...

# %%
df.describe()
# Out:
#        Repetition         ND         GL         LP          TG           GY
# count   48.000000  48.000000  48.000000  48.000000   48.000000    48.000000
# mean     2.000000  33.458333   4.491380   5.108333  538.366517  2525.694444
# std      0.825137  12.729524   1.681830   1.294807   47.946419   590.467603
# min      1.000000  14.000000   1.388889   2.200000  462.023000  1666.666667
# 25%      1.000000  24.750000   3.453125   4.200000  499.735000  2037.500000
# 50%      2.000000  31.500000   4.434211   4.900000  513.272500  2533.333333
# 75%      3.000000  38.250000   5.250513   6.000000  583.552250  2879.166667
# max      3.000000  87.000000   9.000000   8.000000  623.499000  4166.666667
